# %%
import os
import sys
import urllib.request
import json
import pandas as pd
from konlpy.tag import Hannanum
from wordcloud import WordCloud
from collections import Counter
from PIL import Image
import numpy as np
from wordcloud import ImageColorGenerator

# %%
client_id = "VVcgKsFilQFQyluAKBqa"
client_secret = "beM_e268by"
encText = urllib.parse.quote("삼성라이온즈")
# 지식인 = kin 블로그 = blog
# sort = sim(정확도) date(최신순)
url = "https://openapi.naver.com/v1/search/blog?&display=100&sort=date&query=" + encText
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id", client_id)
request.add_header("X-Naver-Client-Secret", client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()

if rescode == 200:
    response_body = response.read()
    decoded_body = response_body.decode('utf-8')

    # JSON 데이터를 파싱하여 출력
    data = json.loads(decoded_body)
    lines = []
    for item in data['items']:
        # 제목과 링크를 합쳐서 한 줄의 문자열로 저장
        line = f"{item['title']} {item['description']}"
        lines.append(line)
else:
    print("Error Code:" + str(rescode))
hannanum = Hannanum()

temp = []
#삼성라이온즈파크 검색결과
for line in lines:
    # '>' 문자를 제거
    clean_line = line.replace('<b>', '').replace('</b>', '') \
                 .replace('>', '') \
                 .replace('#', '') \
                 .replace('삼성', '') \
                 .replace('라이온즈', '') \
                 .replace('대구', '') \
                 .replace('라팍', '') \
                 .replace('파크', '') \
                 .replace('야구', '') \
                 .replace('경기', '') \
                 .replace('중계', '') \
                 .replace('광역시','')
              
    # 명사 추출
    temp.append(hannanum.nouns(clean_line))

def flatten(l):
    flatList = []
    for elem in l:
        if type(elem) == list:
            for e in elem:
                flatList.append(e)
        else:
            flatList.append(elem)
    return flatList

word_list=flatten(temp)
word_list=pd.Series([x for x in word_list if len(x)>1])
font_path = 'NanumBarunGothic.ttf'

wordcloud = WordCloud(
    font_path = font_path,
    width = 800,
    height = 800,
    background_color="white"
)

count = Counter(word_list)
wordcloud = wordcloud.generate_from_frequencies(count)
def __array__(self):
    """Convert to numpy array.
    Returns
    -------
    image : nd-array size (width, height, 3)
        Word cloud image as numpy matrix.
    """
    return self.to_array()

def to_array(self):
    """Convert to numpy array.
    Returns
    -------
    image : nd-array size (width, height, 3)
        Word cloud image as numpy matrix.
    """
    return np.array(self.to_image())
array = wordcloud.to_array()


import matplotlib.pyplot as plt


fig = plt.figure(figsize=(10, 10))
plt.imshow(array, interpolation="bilinear")
plt.show()

# %%
word_list=pd.Series([x for x in word_list if len(x)>1])
word_list.value_counts().head(10)
# Out:
# 8월     28
# 수성구    21
# 승리     16
# 프로     15
# 오늘     15
# 고척     10
# 롯데     10
# 29일    10
# 기아     10
# 마지막     9
# Name: count, dtype: int64

# %% [markdown]
# # 수성구 검색버전

# %%
client_id = "VVcgKsFilQFQyluAKBqa"
client_secret = "beM_e268by"
encText = urllib.parse.quote("수성구")
# 지식인 = kin 블로그 = blog
# sort = sim(정확도) date(최신순)
url = "https://openapi.naver.com/v1/search/blog?&display=100&sort=sim&query=" + encText
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id", client_id)
request.add_header("X-Naver-Client-Secret", client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()

if rescode == 200:
    response_body = response.read()
    decoded_body = response_body.decode('utf-8')

    # JSON 데이터를 파싱하여 출력
    data = json.loads(decoded_body)
    lines = []
    for item in data['items']:
        # 제목과 링크를 합쳐서 한 줄의 문자열로 저장
        line = f"{item['title']} {item['description']}"
        lines.append(line)
else:
    print("Error Code:" + str(rescode))
hannanum = Hannanum()

temp = []
#삼성라이온즈파크 검색결과
for line in lines:
    # '>' 문자를 제거
    clean_line = line.replace('<b>', '').replace('</b>', '') \
                 .replace('>', '') \
                 .replace('#', '') \
                 .replace('삼성', '') \
                 .replace('라이온즈', '') \
                 .replace('대구', '') \
                 .replace('라팍', '') \
                 .replace('파크', '') \
                 .replace('야구', '') \
                 .replace('경기', '') \
                 .replace('00', '') \
                 .replace('수성구','')
              
    # 명사 추출
    temp.append(hannanum.nouns(clean_line))

def flatten(l):
    flatList = []
    for elem in l:
        if type(elem) == list:
            for e in elem:
                flatList.append(e)
        else:
            flatList.append(elem)
    return flatList

word_list=flatten(temp)
word_list=pd.Series([x for x in word_list if len(x)>1])
font_path = 'NanumBarunGothic.ttf'

wordcloud = WordCloud(
    font_path = font_path,
    width = 800,
    height = 800,
    background_color="white"
)

count = Counter(word_list)
wordcloud = wordcloud.generate_from_frequencies(count)
def __array__(self):
    """Convert to numpy array.
    Returns
    -------
    image : nd-array size (width, height, 3)
        Word cloud image as numpy matrix.
    """
    return self.to_array()

def to_array(self):
    """Convert to numpy array.
    Returns
    -------
    image : nd-array size (width, height, 3)
        Word cloud image as numpy matrix.
    """
    return np.array(self.to_image())
array = wordcloud.to_array()


import matplotlib.pyplot as plt


fig = plt.figure(figsize=(10, 10))
plt.imshow(array, interpolation="bilinear")
plt.show()

# %%
word_list=pd.Series([x for x in word_list if len(x)>1])
word_list.value_counts().head(10)
# Out:
# 맛집      77
# 범어동     19
# 들안길     18
# 영업시간    17
# 카페      15
# 가성비     14
# 오늘      14
# 한우      14
# 주소      13
# 지산동     13
# Name: count, dtype: int64

# %%
client_id = "VVcgKsFilQFQyluAKBqa"
client_secret = "beM_e268by"
encText = urllib.parse.quote("삼성라이온즈파크")
# 지식인 = kin 블로그 = blog
# sort = sim(정확도) date(최신순)
url = "https://openapi.naver.com/v1/search/kin?&display=100&sort=date&query=" + encText
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id", client_id)
request.add_header("X-Naver-Client-Secret", client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()

if rescode == 200:
    response_body = response.read()
    decoded_body = response_body.decode('utf-8')

    # JSON 데이터를 파싱하여 출력
    data = json.loads(decoded_body)
    lines = []
    for item in data['items']:
        # 제목과 링크를 합쳐서 한 줄의 문자열로 저장
        line = f"{item['title']} {item['description']}"
        lines.append(line)
else:
    print("Error Code:" + str(rescode))
hannanum = Hannanum()

temp = []
#삼성라이온즈파크 검색결과
for line in lines:
    # '>' 문자를 제거
    clean_line = line.replace('<b>', '').replace('</b>', '') \
                 .replace('>', '') \
                 .replace('#', '') \
                 .replace('삼성', '') \
                 .replace('라이온즈', '') \
                 .replace('대구', '') \
                 .replace('라팍', '') \
                 .replace('파크', '') \
                 .replace('야구', '') \
                 .replace('경기', '') \
                 .replace('1루', '') \
                 .replace('예매','') \
                 .replace('티켓','')
              
    # 명사 추출
    temp.append(hannanum.nouns(clean_line))

def flatten(l):
    flatList = []
    for elem in l:
        if type(elem) == list:
            for e in elem:
                flatList.append(e)
        else:
            flatList.append(elem)
    return flatList

word_list=flatten(temp)
word_list=pd.Series([x for x in word_list if len(x)>1])
font_path = 'NanumBarunGothic.ttf'

wordcloud = WordCloud(
    font_path = font_path,
    width = 800,
    height = 800,
    background_color="white"
)

count = Counter(word_list)
wordcloud = wordcloud.generate_from_frequencies(count)
def __array__(self):
    """Convert to numpy array.
    Returns
    -------
    image : nd-array size (width, height, 3)
        Word cloud image as numpy matrix.
    """
    return self.to_array()

def to_array(self):
    """Convert to numpy array.
    Returns
    -------
    image : nd-array size (width, height, 3)
        Word cloud image as numpy matrix.
    """
    return np.array(self.to_image())
array = wordcloud.to_array()


import matplotlib.pyplot as plt


fig = plt.figure(figsize=(10, 10))
plt.imshow(array, interpolation="bilinear")
plt.show()

# %%
word_list=pd.Series([x for x in word_list if len(x)>1])
word_list.value_counts().head(10)
# Out:
# 원정     16
# 티켓     14
# 좌석     13
# 자리     13
# 응원석    13
# 유니폼    12
# 3루     12
# 질문     11
# 어디     11
# ㅠㅠ     10
# Name: count, dtype: int64

# %%
client_id = "VVcgKsFilQFQyluAKBqa"
client_secret = "beM_e268by"
encText = urllib.parse.quote("삼성라이온즈파크")
# 지식인 = kin 블로그 = blog
# sort = sim(정확도) date(최신순)
url = "https://openapi.naver.com/v1/search/blog?&display=100&sim=date&query=" + encText
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id", client_id)
request.add_header("X-Naver-Client-Secret", client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()

if rescode == 200:
    response_body = response.read()
    decoded_body = response_body.decode('utf-8')

    # JSON 데이터를 파싱하여 출력
    data = json.loads(decoded_body)
    lines = []
    for item in data['items']:
        # 제목과 링크를 합쳐서 한 줄의 문자열로 저장
        line = f"{item['title']} {item['description']}"
        lines.append(line)
else:
    print("Error Code:" + str(rescode))
hannanum = Hannanum()

temp = []
#삼성라이온즈파크 검색결과
for line in lines:
    # '>' 문자를 제거
    clean_line = line.replace('<b>', '').replace('</b>', '') \
                 .replace('>', '') \
                 .replace('#', '') \
                 .replace('', '') \
                 .replace('', '') \
                 .replace('라팍', '') \
                 .replace('파크', '') \
                 .replace('야구', '') \
                 .replace('창원', '') \
                 .replace('대구','') \
                 .replace('8월','') \
                 .replace('근처','') \
                 .replace('라이온즈','')
                  
    # 명사 추출
    temp.append(hannanum.nouns(clean_line))

def flatten(l):
    flatList = []
    for elem in l:
        if type(elem) == list:
            for e in elem:
                flatList.append(e)
        else:
            flatList.append(elem)
    return flatList

word_list=flatten(temp)
word_list=pd.Series([x for x in word_list if len(x)>1])
font_path = 'NanumBarunGothic.ttf'

wordcloud = WordCloud(
    font_path = font_path,
    width = 800,
    height = 800,
    background_color="white"
)

count = Counter(word_list)
wordcloud = wordcloud.generate_from_frequencies(count)
def __array__(self):
    """Convert to numpy array.
    Returns
    -------
    image : nd-array size (width, height, 3)
        Word cloud image as numpy matrix.
    """
    return self.to_array()

def to_array(self):
    """Convert to numpy array.
    Returns
    -------
    image : nd-array size (width, height, 3)
        Word cloud image as numpy matrix.
    """
    return np.array(self.to_image())
array = wordcloud.to_array()


import matplotlib.pyplot as plt


fig = plt.figure(figsize=(10, 10))
plt.imshow(array, interpolation="bilinear")
plt.show()

#워드 클라우드를 이미지로 저장
output_path = 'Samsung_image.png'
fig.savefig(output_path, format='png')

# %%
word_list=pd.Series([x for x in word_list if len(x)>1])
word_list.value_counts().head(10)
# Out:
# 삼성      303
# 좌석       49
# 경기       35
# 직관       26
# 예매       25
# 정보       16
# 먹거리      16
# 주차       15
# 테이블석     15
# 1루       13
# Name: count, dtype: int64
